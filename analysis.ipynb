# %% [markdown]
# ## ANALYSE DE SENTIMENTS

# %% [markdown]
# LIBRAIRIES

# %%
import pyspark
from pyspark import SparkContext
from pyspark.sql import SparkSession, SQLContext
from pyspark.sql.functions import length, regexp_replace, substring, col, udf, isnan, concat_ws, to_timestamp, date_format
from pyspark.sql.types import ArrayType, StringType, IntegerType
from pyspark.ml.feature import Tokenizer

import nltk
import spacy
from pyspark.ml.feature import StopWordsRemover
fr_stopwords = nltk.corpus.stopwords.words('french')
import re

import pandas as pd
from textblob import Blobber
from textblob_fr import PatternTagger, PatternAnalyzer
tb = Blobber(pos_tagger=PatternTagger(), analyzer=PatternAnalyzer())
import pymongo

# %% [markdown]
# OUVERTURE SESSION PYSPARK

# %%
print(pyspark.__version__)
# Out:
# 3.4.0

# %%
## OUVERTURE SESSION SPARK
spark = SparkSession.builder.appName("CSVReader").getOrCreate()
## CHARGEMENT DU CSV
df = spark.read.csv("./data.csv", header=True, inferSchema=True)
#TELECHARGEMENT POUR TOKENISATION
nltk.download('punkt')
#TELECHARGEMENT POUR STOP WORD
nlp = spacy.load("fr_core_news_sm")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\33664\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# NETTOYAGE DES DONNEES

# %%
num_rows = df.count()
num_columns = len(df.columns)

#df_size = num_rows * num_columns

print("Taille du DataFrame :", num_rows)
# Out:
# Taille du DataFrame : 974101

# %%
## NOMS DES COLONNES ET TYPOLOGIE
df
# Out:
# DataFrame[index: string, Datetime: string, Tweet Id: string, Text: string, Like Count: string, Reply Count: string, Retweet Count: string, Quote Count: string, Tweet_Language: string, User_username: string, User_location: string, User_description: string, User_followersCount: string, User_friendsCount: string, User_verified: string, User_favouritesCount: string, User_statusesCount: string, User_listedCount: string, User_url: string, User_created: string, User_profileImageUrl: string, Query: string]

# %%
## SUPRESSIONS DES COLONNES
df = df.drop("index","Tweet_Language","User_friendsCount","User_statusesCount","User_listedCount","User_favouritesCount","User_url","User_created","User_profileImageUrl","Query","User_location")

# %%
## CONVERTION INT
columns_to_convert = ["Like Count", "Reply Count", "Retweet Count", "Quote Count", "User_followersCount"]
for column in columns_to_convert:
    df = df.withColumn(column, col(column).cast(IntegerType()))

# %%
## NOMS DES COLONNES ET TYPOLOGIE
df
# Out:
# DataFrame[Datetime: string, Tweet Id: string, Text: string, Like Count: int, Reply Count: int, Retweet Count: int, Quote Count: int, User_username: string, User_description: string, User_followersCount: int, User_verified: string]

# %%
## SUPPRESSIONS DES LIGNES ERRONEES CERTIF
valid_values = ["False", "null", "True"]
df = df.filter(df.User_verified.isin(valid_values))

# %%
## SUPRESSIONS DES CARACTERES TEXT
df = df.withColumn("Text", regexp_replace(df.Text, r"@\w+", ""))
df = df.withColumn("Text", regexp_replace(df.Text, r"https\S+", ""))
df = df.withColumn("Text", regexp_replace(df.Text, "#ReformeDesRetraites", ""))

# %%
# Filtrer les lignes sans aucun caractère alphanumériques dans la colonne "Text" (permet de supprimer les vides)
df = df.filter(col("Text").rlike("[A-Za-z0-9]"))

df.show(5)
# Out:
# +--------------------+-------------------+--------------------+----------+-----------+-------------+-----------+--------------+--------------------+-------------------+-------------+
# |            Datetime|           Tweet Id|                Text|Like Count|Reply Count|Retweet Count|Quote Count| User_username|    User_description|User_followersCount|User_verified|
# +--------------------+-------------------+--------------------+----------+-----------+-------------+-----------+--------------+--------------------+-------------------+-------------+
# |2023-04-02 20:42:...|1642598362414301184| un faux compte ?...|         0|          0|            0|          0|zitounbraghini|                null|                 18|        False|
# |2023-04-02 20:40:...|1642597945634611202|👏🥳 Cette victoi...|         0|          0|            0|          0|CorbierVincent|En marche dans le...|                121|        False|
# |2023-04-02 20:36:...|1642596869741182979|Le 6 avril, grève...|         1|          0|            1|          0| Mercypolitics|French author of ...|               3959|        False|
# |2023-04-02 20:27:...|1642594657312862208|sauver les instit...|         0|          0|            0|          0|      Ys_ambre|Les fantôme ne so...|                206|        False|
# |2023-04-02 20:26:...|1642594332182999042|Qui sème le vent ...|         0|          0|            0|          0|zitounbraghini|                null|                 18|        False|
# +--------------------+-------------------+--------------------+----------+-----------+-------------+-----------+--------------+--------------------+-------------------+-------------+
# only showing top 5 rows

# %%
## SUPPRESSIONS DES LIGNES ERRONEES
df = df.filter(length(df.Datetime) >= 10)
#Filtrer les lignes DATETIME
df = df.filter(~col("datetime").rlike("[a-zA-Z]"))

# %%
#RACCOURIR DATETIME
df = df.withColumn("Datetime", substring("Datetime", 1, 19))
df.show(5)
# Out:
# +-------------------+-------------------+--------------------+----------+-----------+-------------+-----------+--------------+--------------------+-------------------+-------------+
# |           Datetime|           Tweet Id|                Text|Like Count|Reply Count|Retweet Count|Quote Count| User_username|    User_description|User_followersCount|User_verified|
# +-------------------+-------------------+--------------------+----------+-----------+-------------+-----------+--------------+--------------------+-------------------+-------------+
# |2023-04-02 20:42:22|1642598362414301184| un faux compte ?...|         0|          0|            0|          0|zitounbraghini|                null|                 18|        False|
# |2023-04-02 20:40:42|1642597945634611202|👏🥳 Cette victoi...|         0|          0|            0|          0|CorbierVincent|En marche dans le...|                121|        False|
# |2023-04-02 20:36:26|1642596869741182979|Le 6 avril, grève...|         1|          0|            1|          0| Mercypolitics|French author of ...|               3959|        False|
# |2023-04-02 20:27:38|1642594657312862208|sauver les instit...|         0|          0|            0|          0|      Ys_ambre|Les fantôme ne so...|                206|        False|
# |2023-04-02 20:26:21|1642594332182999042|Qui sème le vent ...|         0|          0|            0|          0|zitounbraghini|                null|                 18|        False|
# +-------------------+-------------------+--------------------+----------+-----------+-------------+-----------+--------------+--------------------+-------------------+-------------+
# only showing top 5 rows

# %%
df = df.withColumn("Datetime", to_timestamp(col("Datetime"), "yyyy-MM-dd HH:mm:ss"))

# %%
df
# Out:
# DataFrame[Datetime: timestamp, Tweet Id: string, Text: string, Like Count: int, Reply Count: int, Retweet Count: int, Quote Count: int, User_username: string, User_description: string, User_followersCount: int, User_verified: string]

# %%
df.printSchema()
# Out:
# root
#  |-- Datetime: timestamp (nullable = true)
#  |-- Tweet Id: string (nullable = true)
#  |-- Text: string (nullable = true)
#  |-- Like Count: integer (nullable = true)
#  |-- Reply Count: integer (nullable = true)
#  |-- Retweet Count: integer (nullable = true)
#  |-- Quote Count: integer (nullable = true)
#  |-- User_username: string (nullable = true)
#  |-- User_description: string (nullable = true)
#  |-- User_followersCount: integer (nullable = true)
#  |-- User_verified: string (nullable = true)

# %% [markdown]
# ANALYSE DE SENTIMENT

# %%
#TOKENIZATION
tokenizer = Tokenizer(inputCol="Text", outputCol="Words")
df = tokenizer.transform(df)

# %%
df.show(5)
# Out:
# +-------------------+-------------------+--------------------+----------+-----------+-------------+-----------+--------------+--------------------+-------------------+-------------+--------------------+
# |           Datetime|           Tweet Id|                Text|Like Count|Reply Count|Retweet Count|Quote Count| User_username|    User_description|User_followersCount|User_verified|               Words|
# +-------------------+-------------------+--------------------+----------+-----------+-------------+-----------+--------------+--------------------+-------------------+-------------+--------------------+
# |2023-04-02 20:42:22|1642598362414301184| un faux compte ?...|         0|          0|            0|          0|zitounbraghini|                null|                 18|        False|[, un, faux, comp...|
# |2023-04-02 20:40:42|1642597945634611202|👏🥳 Cette victoi...|         0|          0|            0|          0|CorbierVincent|En marche dans le...|                121|        False|[👏🥳, cette, vic...|
# |2023-04-02 20:36:26|1642596869741182979|Le 6 avril, grève...|         1|          0|            1|          0| Mercypolitics|French author of ...|               3959|        False|[le, 6, avril,, g...|
# |2023-04-02 20:27:38|1642594657312862208|sauver les instit...|         0|          0|            0|          0|      Ys_ambre|Les fantôme ne so...|                206|        False|[sauver, les, ins...|
# |2023-04-02 20:26:21|1642594332182999042|Qui sème le vent ...|         0|          0|            0|          0|zitounbraghini|                null|                 18|        False|[qui, sème, le, v...|
# +-------------------+-------------------+--------------------+----------+-----------+-------------+-----------+--------------+--------------------+-------------------+-------------+--------------------+
# only showing top 5 rows

# %%
swr = StopWordsRemover(inputCol="Words", outputCol="FilteredWords", stopWords=fr_stopwords)
SwRemoved = swr.transform(df)
SwRemoved.show(truncate=False, n=5)
# Out:
# +-------------------+-------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-----------+-------------+-----------+--------------+------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Datetime           |Tweet Id           |Text                                                                                                                                                                                                                                              |Like Count|Reply Count|Retweet Count|Quote Count|User_username |User_description                                                                                                                                            |User_followersCount|User_verified|Words                                                                                                                                                                                                                                                                                     |FilteredWords                                                                                                                                                                                                    |
# +-------------------+-------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-----------+-------------+-----------+--------------+------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2023-04-02 20:42:22|1642598362414301184| un faux compte ? Problème : l’article de France Info date de juin 2022 et le compte présent a été créé  en août 2022 😅 Qui se cache derrière ce compte ? 🤔 #retraites #censurepopulaire #macronie                                              |0         |0          |0            |0          |zitounbraghini|null                                                                                                                                                        |18                 |False        |[, un, faux, compte, ?, problème, :, l’article, de, france, info, date, de, juin, 2022, et, le, compte, présent, a, été, créé, , en, août, 2022, 😅, qui, se, cache, derrière, ce, compte, ?, 🤔, #retraites, #censurepopulaire, #macronie]                                               |[, faux, compte, ?, problème, :, l’article, france, info, date, juin, 2022, compte, présent, a, créé, , août, 2022, 😅, cache, derrière, compte, ?, 🤔, #retraites, #censurepopulaire, #macronie]                |
# |2023-04-02 20:40:42|1642597945634611202|👏🥳 Cette victoire est un message de fermeté de la part des électeurs qui sont majoritairement pour la  ! Ce n'est pas le terrorisme intellectuel et la violence de l'ultra gauche qui doit l'emporter ! #NousReussirons #Renaissance            |0         |0          |0            |0          |CorbierVincent|En marche dans le 78 depuis 2016 - Anti-Gilets Jaunes & NUPES #LégitimitéDémocratique #Bienveillance #FREM #ConvergenceDesLuttes #Renaissance #MACRON4EVER  |121                |False        |[👏🥳, cette, victoire, est, un, message, de, fermeté, de, la, part, des, électeurs, qui, sont, majoritairement, pour, la, , !, ce, n'est, pas, le, terrorisme, intellectuel, et, la, violence, de, l'ultra, gauche, qui, doit, l'emporter, !, #nousreussirons, #renaissance]             |[👏🥳, cette, victoire, message, fermeté, part, électeurs, majoritairement, , !, n'est, terrorisme, intellectuel, violence, l'ultra, gauche, doit, l'emporter, !, #nousreussirons, #renaissance]                 |
# |2023-04-02 20:36:26|1642596869741182979|Le 6 avril, grève générale !  via  #Melenchon derniere interview complete.  #ViolencesPolicieres #greve6avril #GreveGenerale #LFI                                                                                                                 |1         |0          |1            |0          |Mercypolitics |French author of The Orwellian Empire journalist,on air analyst, photojournalist & filmmaker based in the US since 1983.Editor in chief of News Junkie Post.|3959               |False        |[le, 6, avril,, grève, générale, !, , via, , #melenchon, derniere, interview, complete., , #violencespolicieres, #greve6avril, #grevegenerale, #lfi]                                                                                                                                      |[6, avril,, grève, générale, !, , via, , #melenchon, derniere, interview, complete., , #violencespolicieres, #greve6avril, #grevegenerale, #lfi]                                                                 |
# |2023-04-02 20:27:38|1642594657312862208|sauver les institutions !! sinon un sénateur risque de mourir de faim !!!  vite une cagnotte contre le vil vil Melenchon !                                                                                                                        |0         |0          |0            |0          |Ys_ambre      |Les fantôme ne sont pas avares, ici Londres, maintenant la suite de nos informations                                                                        |206                |False        |[sauver, les, institutions, !!, sinon, un, sénateur, risque, de, mourir, de, faim, !!!, , vite, une, cagnotte, contre, le, vil, vil, melenchon, !]                                                                                                                                        |[sauver, institutions, !!, sinon, sénateur, risque, mourir, faim, !!!, , vite, cagnotte, contre, vil, vil, melenchon, !]                                                                                         |
# |2023-04-02 20:26:21|1642594332182999042|Qui sème le vent récolte la tempête ! Vous découvrez ainsi qu’il existe des gens aussi méchants que vous 🙄. Remarquez que ce ne sont pas des appels au meurtre juste des calamités naturelles invoquées 🤔 #macronie #retraites #censurepopulaire|0         |0          |0            |0          |zitounbraghini|null                                                                                                                                                        |18                 |False        |[qui, sème, le, vent, récolte, la, tempête, !, vous, découvrez, ainsi, qu’il, existe, des, gens, aussi, méchants, que, vous, 🙄., remarquez, que, ce, ne, sont, pas, des, appels, au, meurtre, juste, des, calamités, naturelles, invoquées, 🤔, #macronie, #retraites, #censurepopulaire]|[sème, vent, récolte, tempête, !, découvrez, ainsi, qu’il, existe, gens, aussi, méchants, 🙄., remarquez, appels, meurtre, juste, calamités, naturelles, invoquées, 🤔, #macronie, #retraites, #censurepopulaire]|
# +-------------------+-------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-----------+-------------+-----------+--------------+------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
df = SwRemoved.withColumn("FilteredWordsString", concat_ws(" ", SwRemoved.FilteredWords))

# %% [markdown]
# Conversion Pandas

# %%
# Convertir la DataFrame PySpark en pandas DataFrame
pdf = df.toPandas()
# Out:
# c:\Users\33664\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\pandas\conversion.py:251: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)

# %%
senti_list = []
for i in pdf["FilteredWordsString"]:
    vs = tb(i).sentiment[0]
    if (vs > 0):
        senti_list.append('Satisfait')
    elif (vs < 0):
        senti_list.append('Insatisfait')
    else:
        senti_list.append('Neutre')   

pdf["sentiment_class"]=senti_list

# %%
pdf
# Out:
#                   Datetime             Tweet Id  \
# 0      2023-04-02 20:42:22  1642598362414301184
# 1      2023-04-02 20:40:42  1642597945634611202
# 2      2023-04-02 20:36:26  1642596869741182979
# 3      2023-04-02 20:27:38  1642594657312862208
# 4      2023-04-02 20:26:21  1642594332182999042
# ...                    ...                  ...
# 105777 2023-04-16 07:14:43  1647468541438836737
# 105778 2023-04-16 07:14:32  1647468493783064577
# 105779 2023-04-17 00:07:39  1647723456845193219
# 105780 2023-04-17 01:07:15  1647738455256965124
# 105781 2023-04-17 01:05:34  1647738030466162689
#
#                                                      Text  Like Count  \
# 0        un faux compte ? Problème : l’article de Fran...           0
# 1       👏🥳 Cette victoire est un message de fermeté de...           0
# 2       Le 6 avril, grève générale !  via  #Melenchon ...           1
# 3       sauver les institutions !! sinon un sénateur r...           0
# 4       Qui sème le vent récolte la tempête ! Vous déc...           0
# ...                                                   ...         ...
# 105777    Malgré la décision du #Conseil_Constitutionn...           0
# 105778   La france va pourrir tes J.O... #réformedesre...           1
# 105779  Et de temps en temps, la lucidité fait irrupti...           0
# 105780                                       #Macron20h             0
# 105781  23/04/17-01H05  #photodujour #Manif6Avril #Réf...           0
#
#         Reply Count  Retweet Count  Quote Count    User_username  \
# 0                 0              0            0   zitounbraghini
# 1                 0              0            0   CorbierVincent
# 2                 0              1            0    Mercypolitics
# 3                 0              0            0         Ys_ambre
# 4                 0              0            0   zitounbraghini
# ...             ...            ...          ...              ...
# 105777            1              0            0  brestoisdu29200
# 105778            0              0            0         greghs74
# 105779            0              0            0         aw3rty92
# 105780            0              0            0   Hersh__Bathens
# 105781            0              0            0          jp91310
#
#                                          User_description  \
# 0                                                    None
# 1       En marche dans le 78 depuis 2016 - Anti-Gilets...
# 2       French author of The Orwellian Empire journali...
# 3       Les fantôme ne sont pas avares, ici Londres, m...
# 4                                                    None
# ...                                                   ...
# 105777  Ami de notre Président de la République França...
# 105778                                               None
# 105779  Get your fix of politics and entertainment wit...
# 105780                      Ex dormeur, enfin réveillé...
# 105781                                               None
#
#         User_followersCount User_verified  \
# 0                        18         False
# 1                       121         False
# 2                      3959         False
# 3                       206         False
# 4                        18         False
# ...                     ...           ...
# 105777                   30         False
# 105778                  153         False
# 105779                   12         False
# 105780                  318         False
# 105781                    1         False
#
#                                                     Words  \
# 0       [, un, faux, compte, ?, problème, :, l’article...
# 1       [👏🥳, cette, victoire, est, un, message, de, fe...
# 2       [le, 6, avril,, grève, générale, !, , via, , #...
# 3       [sauver, les, institutions, !!, sinon, un, sén...
# 4       [qui, sème, le, vent, récolte, la, tempête, !,...
# ...                                                   ...
# 105777  [, , malgré, la, décision, du, #conseil_consti...
# 105778  [, la, france, va, pourrir, tes, j.o..., #réfo...
# 105779  [et, de, temps, en, temps,, la, lucidité, fait...
# 105780                                       [#macron20h]
# 105781  [23/04/17-01h05, , #photodujour, #manif6avril,...
#
#                                             FilteredWords  \
# 0       [, faux, compte, ?, problème, :, l’article, fr...
# 1       [👏🥳, cette, victoire, message, fermeté, part, ...
# 2       [6, avril,, grève, générale, !, , via, , #mele...
# 3       [sauver, institutions, !!, sinon, sénateur, ri...
# 4       [sème, vent, récolte, tempête, !, découvrez, a...
# ...                                                   ...
# 105777  [, , malgré, décision, #conseil_constitutionne...
# 105778  [, france, va, pourrir, j.o..., #réformedesret...
# 105779  [temps, temps,, lucidité, fait, irruption, sur...
# 105780                                       [#macron20h]
# 105781  [23/04/17-01h05, , #photodujour, #manif6avril,...
#
#                                       FilteredWordsString sentiment_class
# 0        faux compte ? problème : l’article france inf...     Insatisfait
# 1       👏🥳 cette victoire message fermeté part électeu...     Insatisfait
# 2       6 avril, grève générale !  via  #melenchon der...       Satisfait
# 3       sauver institutions !! sinon sénateur risque m...          Neutre
# 4       sème vent récolte tempête ! découvrez ainsi qu...       Satisfait
# ...                                                   ...             ...
# 105777    malgré décision #conseil_constitutionnel va ...       Satisfait
# 105778      france va pourrir j.o... #réformedesretraites          Neutre
# 105779  temps temps, lucidité fait irruption surprise ...       Satisfait
# 105780                                         #macron20h          Neutre
# 105781  23/04/17-01h05  #photodujour #manif6avril #réf...          Neutre
#
# [105782 rows x 15 columns]

# %%
#Création de la colonne sentiment_class
#pdf.loc[pdf["sentiment"] > 0, "sentiment_class"] = 'Satisfait'
#pdf.loc[pdf["sentiment"] < 0, "sentiment_class"] = 'Insatisfait'
#pdf.loc[pdf["sentiment"] == 0, "sentiment_class"] = 'Neutre'

# %%
#Création de la colonne sentiment_class_details
#pdf.loc[pdf["sentiment"] > 0.5, "sentiment_class_details"] = 'Très Satisfait'
#pdf.loc[(pdf["sentiment"] > 0) & (pdf["sentiment"] < 0.5), "sentiment_class_details"] = 'Satisfait'
#pdf.loc[pdf["sentiment"] == 0, "sentiment_class_details"] = 'Neutre'
#pdf.loc[(pdf["sentiment"] > -0.5) & (pdf["sentiment"] < 0), "sentiment_class_details"] = 'Satisfait'
#pdf.loc[pdf["sentiment"] < -0.5, "sentiment_class_details"] = 'Très Insatisfait'

#pdf.head()

# %%
#SUPPRIMER COLONNES NON NECESSAIRES
pdf = pdf.drop(columns=["FilteredWords", "Words"])

# %%
pdf
# Out:
#                   Datetime             Tweet Id  \
# 0      2023-04-02 20:42:22  1642598362414301184
# 1      2023-04-02 20:40:42  1642597945634611202
# 2      2023-04-02 20:36:26  1642596869741182979
# 3      2023-04-02 20:27:38  1642594657312862208
# 4      2023-04-02 20:26:21  1642594332182999042
# ...                    ...                  ...
# 105777 2023-04-16 07:14:43  1647468541438836737
# 105778 2023-04-16 07:14:32  1647468493783064577
# 105779 2023-04-17 00:07:39  1647723456845193219
# 105780 2023-04-17 01:07:15  1647738455256965124
# 105781 2023-04-17 01:05:34  1647738030466162689
#
#                                                      Text  Like Count  \
# 0        un faux compte ? Problème : l’article de Fran...           0
# 1       👏🥳 Cette victoire est un message de fermeté de...           0
# 2       Le 6 avril, grève générale !  via  #Melenchon ...           1
# 3       sauver les institutions !! sinon un sénateur r...           0
# 4       Qui sème le vent récolte la tempête ! Vous déc...           0
# ...                                                   ...         ...
# 105777    Malgré la décision du #Conseil_Constitutionn...           0
# 105778   La france va pourrir tes J.O... #réformedesre...           1
# 105779  Et de temps en temps, la lucidité fait irrupti...           0
# 105780                                       #Macron20h             0
# 105781  23/04/17-01H05  #photodujour #Manif6Avril #Réf...           0
#
#         Reply Count  Retweet Count  Quote Count    User_username  \
# 0                 0              0            0   zitounbraghini
# 1                 0              0            0   CorbierVincent
# 2                 0              1            0    Mercypolitics
# 3                 0              0            0         Ys_ambre
# 4                 0              0            0   zitounbraghini
# ...             ...            ...          ...              ...
# 105777            1              0            0  brestoisdu29200
# 105778            0              0            0         greghs74
# 105779            0              0            0         aw3rty92
# 105780            0              0            0   Hersh__Bathens
# 105781            0              0            0          jp91310
#
#                                          User_description  \
# 0                                                    None
# 1       En marche dans le 78 depuis 2016 - Anti-Gilets...
# 2       French author of The Orwellian Empire journali...
# 3       Les fantôme ne sont pas avares, ici Londres, m...
# 4                                                    None
# ...                                                   ...
# 105777  Ami de notre Président de la République França...
# 105778                                               None
# 105779  Get your fix of politics and entertainment wit...
# 105780                      Ex dormeur, enfin réveillé...
# 105781                                               None
#
#         User_followersCount User_verified  \
# 0                        18         False
# 1                       121         False
# 2                      3959         False
# 3                       206         False
# 4                        18         False
# ...                     ...           ...
# 105777                   30         False
# 105778                  153         False
# 105779                   12         False
# 105780                  318         False
# 105781                    1         False
#
#                                       FilteredWordsString sentiment_class
# 0        faux compte ? problème : l’article france inf...     Insatisfait
# 1       👏🥳 cette victoire message fermeté part électeu...     Insatisfait
# 2       6 avril, grève générale !  via  #melenchon der...       Satisfait
# 3       sauver institutions !! sinon sénateur risque m...          Neutre
# 4       sème vent récolte tempête ! découvrez ainsi qu...       Satisfait
# ...                                                   ...             ...
# 105777    malgré décision #conseil_constitutionnel va ...       Satisfait
# 105778      france va pourrir j.o... #réformedesretraites          Neutre
# 105779  temps temps, lucidité fait irruption surprise ...       Satisfait
# 105780                                         #macron20h          Neutre
# 105781  23/04/17-01h05  #photodujour #manif6avril #réf...          Neutre
#
# [105782 rows x 13 columns]

# %% [markdown]
# Exportation vers MongoDB Compass

# %%
client = pymongo.MongoClient ("mongodb://localhost:27017")

# %%
db = client["twitter_analysis"]

# %%
data = pdf.to_dict(orient="record")
# Out:
# C:\Users\33664\AppData\Local\Temp\ipykernel_49160\2187062943.py:1: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   data = pdf.to_dict(orient="record")

# %%
data
# Out:
# [{'Datetime': Timestamp('2023-04-02 20:42:22'),
#   'Tweet Id': '1642598362414301184',
#   'Text': ' un faux compte ? Problème : l’article de France Info date de juin 2022 et le compte présent a été créé  en août 2022 😅 Qui se cache derrière ce compte ? 🤔 #retraites #censurepopulaire #macronie',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'zitounbraghini',
#   'User_description': None,
#   'User_followersCount': 18,
#   'User_verified': 'False',
#   'FilteredWordsString': ' faux compte ? problème : l’article france info date juin 2022 compte présent a créé  août 2022 😅 cache derrière compte ? 🤔 #retraites #censurepopulaire #macronie',
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-04-02 20:40:42'),
#   'Tweet Id': '1642597945634611202',
#   'Text': "👏🥳 Cette victoire est un message de fermeté de la part des électeurs qui sont majoritairement pour la  ! Ce n'est pas le terrorisme intellectuel et la violence de l'ultra gauche qui doit l'emporter ! #NousReussirons #Renaissance",
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'CorbierVincent',
#   'User_description': 'En marche dans le 78 depuis 2016 - Anti-Gilets Jaunes & NUPES #LégitimitéDémocratique #Bienveillance #FREM #ConvergenceDesLuttes #Renaissance #MACRON4EVER',
#   'User_followersCount': 121,
#   'User_verified': 'False',
#   'FilteredWordsString': "👏🥳 cette victoire message fermeté part électeurs majoritairement  ! n'est terrorisme intellectuel violence l'ultra gauche doit l'emporter ! #nousreussirons #renaissance",
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-04-02 20:36:26'),
#   'Tweet Id': '1642596869741182979',
#   'Text': 'Le 6 avril, grève générale !  via  #Melenchon derniere interview complete.  #ViolencesPolicieres #greve6avril #GreveGenerale #LFI',
#   'Like Count': 1,
#   'Reply Count': 0,
#   'Retweet Count': 1,
#   'Quote Count': 0,
#   'User_username': 'Mercypolitics',
#   'User_description': 'French author of The Orwellian Empire journalist,on air analyst, photojournalist & filmmaker based in the US since 1983.Editor in chief of News Junkie Post.',
#   'User_followersCount': 3959,
#   'User_verified': 'False',
#   'FilteredWordsString': '6 avril, grève générale !  via  #melenchon derniere interview complete.  #violencespolicieres #greve6avril #grevegenerale #lfi',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 20:27:38'),
#   'Tweet Id': '1642594657312862208',
#   'Text': 'sauver les institutions !! sinon un sénateur risque de mourir de faim !!!  vite une cagnotte contre le vil vil Melenchon !',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'Ys_ambre',
#   'User_description': 'Les fantôme ne sont pas avares, ici Londres, maintenant la suite de nos informations',
#   'User_followersCount': 206,
#   'User_verified': 'False',
#   'FilteredWordsString': 'sauver institutions !! sinon sénateur risque mourir faim !!!  vite cagnotte contre vil vil melenchon !',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 20:26:21'),
#   'Tweet Id': '1642594332182999042',
#   'Text': 'Qui sème le vent récolte la tempête ! Vous découvrez ainsi qu’il existe des gens aussi méchants que vous 🙄. Remarquez que ce ne sont pas des appels au meurtre juste des calamités naturelles invoquées 🤔 #macronie #retraites #censurepopulaire',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'zitounbraghini',
#   'User_description': None,
#   'User_followersCount': 18,
#   'User_verified': 'False',
#   'FilteredWordsString': 'sème vent récolte tempête ! découvrez ainsi qu’il existe gens aussi méchants 🙄. remarquez appels meurtre juste calamités naturelles invoquées 🤔 #macronie #retraites #censurepopulaire',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 20:23:34'),
#   'Tweet Id': '1642593632245915651',
#   'Text': 'Le président du sénat  sur : «\xa0les français doivent comprendre que cette  est indispensable\xa0».Alors pourquoi avez-vous supprimé les régimes spéciaux sauf celui des sénateurs dont le vôtre ?Vous ne faites pas partie des français sacrifiés ?',
#   'Like Count': 2,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'enquetes_jc',
#   'User_description': "Rédacteur en chef & JRI carte de presse. Mes tweets n'engagent que moi.🇫🇷🇵🇱🇺🇦",
#   'User_followersCount': 386,
#   'User_verified': 'False',
#   'FilteredWordsString': 'président sénat  : «\xa0les français doivent comprendre cette  indispensable\xa0».alors pourquoi avez-vous supprimé régimes spéciaux sauf celui sénateurs dont vôtre ?vous faites partie français sacrifiés ?',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 20:22:38'),
#   'Tweet Id': '1642593395586609154',
#   'Text': ' répond d’une manœuvre magistrate aux insoumis, nous n’avons pas besoin de vous diaboliser, vous le faites très bien tout seul!!  ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'belilan',
#   'User_description': 'Je débats politique et sujets d’actualité, ne réponds pas aux insultes (blocage immédiat). #NIKKIHALEY2024',
#   'User_followersCount': 147,
#   'User_verified': 'False',
#   'FilteredWordsString': ' répond d’une manœuvre magistrate insoumis, n’avons besoin diaboliser, faites très bien tout seul!!',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 20:22:36'),
#   'Tweet Id': '1642593388892397570',
#   'Text': ' Ça va se reconvertir sossedem si tôt le quinquennat fini ! Et faudra pas oublier : #SainteSoline  #Darmanin ect...',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'VDauzet',
#   'User_description': None,
#   'User_followersCount': 8,
#   'User_verified': 'False',
#   'FilteredWordsString': ' ça va reconvertir sossedem si tôt quinquennat fini ! faudra oublier : #saintesoline  #darmanin ect...',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 20:22:06'),
#   'Tweet Id': '1642593262803333121',
#   'Text': "c'est bizarre j'ai pas de tag  ;)",
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'lepindev',
#   'User_description': 'Tech & Bio',
#   'User_followersCount': 486,
#   'User_verified': 'False',
#   'FilteredWordsString': "c'est bizarre j'ai tag  ;)",
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-04-02 20:20:06'),
#   'Tweet Id': '1642592758241034242',
#   'Text': "Près de 200 personnes sont passées à notre Fest-deiz de soutien à la caisse de #Greve à Guingamp. Merci à tous et toutes pour ce moment de solidarité et convivialité prolétaire à la mode de #Bretagne . A très vite dans la rue !  Betek an trec'h ! #bzh ",
#   'Like Count': 4,
#   'Reply Count': 1,
#   'Retweet Count': 3,
#   'Quote Count': 0,
#   'User_username': 'CGTGwengamp',
#   'User_description': "Union Locale de la #CGT #Guingamp/Unvaniezh Lec'hel CGT #Gwengamp #LuttesDesClasses",
#   'User_followersCount': 140,
#   'User_verified': 'False',
#   'FilteredWordsString': "près 200 personnes passées fest-deiz soutien caisse #greve guingamp. merci tous toutes moment solidarité convivialité prolétaire mode #bretagne . a très vite rue !  betek an trec'h ! #bzh",
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 20:20:04'),
#   'Tweet Id': '1642592749760151553',
#   'Text': '"Écoutez la charge de ce journaliste contre #Macron ""2ans de mensonges de gabegies financières avc 400 milliards € dépensés pour une maladie qui a moins tué que la gestion de crise #covid en elle même "" Harold Luce présentateur à  👏 #Guadeloupe "',
#   'Like Count': 2,
#   'Reply Count': 0,
#   'Retweet Count': 2,
#   'Quote Count': 0,
#   'User_username': 'ActusNonStop',
#   'User_description': "journaliste indépendant au cœur de l'actualité politique, nationale et internationale. également présent sur Facebook facebook.com/ActusNonStop/",
#   'User_followersCount': 43549,
#   'User_verified': 'False',
#   'FilteredWordsString': '"écoutez charge journaliste contre #macron ""2ans mensonges gabegies financières avc 400 milliards € dépensés maladie a moins tué gestion crise #covid "" harold luce présentateur  👏 #guadeloupe "',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 20:19:55'),
#   'Tweet Id': '1642592713701769217',
#   'Text': 'Parce qu’ils ont eu le choix ? D’ailleurs pas de remerciement pour leurs enseignants qui n’étaient peut-être pas enthousiastes 😅 : le discours dégoulinant d’hypocrisie ne sentait pas la lavande 🤮  #retraites #censurepopulaire #macronie',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'zitounbraghini',
#   'User_description': None,
#   'User_followersCount': 18,
#   'User_verified': 'False',
#   'FilteredWordsString': 'parce qu’ils choix ? d’ailleurs remerciement leurs enseignants n’étaient peut-être enthousiastes 😅 : discours dégoulinant d’hypocrisie sentait lavande 🤮  #retraites #censurepopulaire #macronie',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 20:18:04'),
#   'Tweet Id': '1642592249228718080',
#   'Text': " ??.. regardez où vont passer 10 milliards d'euros qui aurait pu financer... Dans le prochain porte-avion nucléaire.. C'était au journal de TF1 il y a qqs minutes ce dimanche soir....",
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'Robyn_Des_Bois',
#   'User_description': "j'essaie d'être drôle et spirituel...pas toujours une réussite 😅...et puis on aura bientôt que trop  d'occasion de pleurer...",
#   'User_followersCount': 0,
#   'User_verified': 'False',
#   'FilteredWordsString': " ??.. regardez où vont passer 10 milliards d'euros pu financer... prochain porte-avion nucléaire.. c'était journal tf1 a qqs minutes dimanche soir....",
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 20:17:42'),
#   'Tweet Id': '1642592156794642433',
#   'Text': 'Je vote LFI, opposé à la  et au saccage des espaces ruraux par les bulldozers capitalistes, donc #jesuisunterroristeintellectuel',
#   'Like Count': 0,
#   'Reply Count': 1,
#   'Retweet Count': 1,
#   'Quote Count': 0,
#   'User_username': 'LimaceBoiteuse',
#   'User_description': 'Troll amateur',
#   'User_followersCount': 431,
#   'User_verified': 'False',
#   'FilteredWordsString': 'vote lfi, opposé  saccage espaces ruraux bulldozers capitalistes, donc #jesuisunterroristeintellectuel',
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-04-02 20:09:49'),
#   'Tweet Id': '1642590170804367360',
#   'Text': 'Ne pas manquer le rendez vous avec les anciens surtout mais éviter la foule de terroristes intellectuels la veille 🤣   #macronie #censurepopulaire #retraites',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'zitounbraghini',
#   'User_description': None,
#   'User_followersCount': 18,
#   'User_verified': 'False',
#   'FilteredWordsString': 'manquer rendez anciens surtout éviter foule terroristes intellectuels veille 🤣   #macronie #censurepopulaire #retraites',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 20:07:22'),
#   'Tweet Id': '1642589553482518530',
#   'Text': 'Notre époque est formidable ‼️. Voilà un Pdt du #Senat qui nous explique que la #reformedesretraites est un bonne chose alors même qu’il défend le statut autonome ( #régimespécial) dont bénéficient ses pairs sénateurs, donc financé par nous-mêmes ! #BFMtv.',
#   'Like Count': 1,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'Biancone2',
#   'User_description': 'Commissaire salon du livre HOSSEGOR. conseiller municipal. « Si tous ceux qui croient avoir raison n’avaient pas tort, la vérité ne serait pas loin»',
#   'User_followersCount': 2038,
#   'User_verified': 'False',
#   'FilteredWordsString': 'époque formidable ‼️. voilà pdt #senat explique #reformedesretraites bonne chose alors qu’il défend statut autonome ( #régimespécial) dont bénéficient pairs sénateurs, donc financé nous-mêmes ! #bfmtv.',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 20:05:50'),
#   'Tweet Id': '1642589168982188035',
#   'Text': '23/04/02-20H05 . #photodujour #Macron13h #RéformeDesRetraites ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'jp91310',
#   'User_description': None,
#   'User_followersCount': 1,
#   'User_verified': 'False',
#   'FilteredWordsString': '23/04/02-20h05 . #photodujour #macron13h #réformedesretraites',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 19:28:36'),
#   'Tweet Id': '1642579799888613376',
#   'Text': '#retrait ',
#   'Like Count': 2,
#   'Reply Count': 0,
#   'Retweet Count': 1,
#   'Quote Count': 0,
#   'User_username': 'DavidJohnTarhn',
#   'User_description': None,
#   'User_followersCount': 752,
#   'User_verified': 'False',
#   'FilteredWordsString': '#retrait',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 20:03:47'),
#   'Tweet Id': '1642588654991187969',
#   'Text': "  C'est la  qui le perturbe ! Allez, le retrait de cette réforme ! y en a qui bosse  ! 😂",
#   'Like Count': 1,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'ManuelleYerly',
#   'User_description': 'A quoi bon se résigner ? (100% connerie naturelle)🦰Pour une connerie démocratique. pour un numérique non fasciste.',
#   'User_followersCount': 201,
#   'User_verified': 'False',
#   'FilteredWordsString': "  c'est  perturbe ! allez, retrait cette réforme ! a bosse  ! 😂",
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 20:03:14'),
#   'Tweet Id': '1642588514008137728',
#   'Text': 'Bon appétit Gérard, pdt que certains citoyens ont à peine de quoi manger avec l’#inflation et que presque tous (sauf les élus) sont pénalisés par la  #Senat #macronie #censurepopulaire #retraites',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'zitounbraghini',
#   'User_description': None,
#   'User_followersCount': 18,
#   'User_verified': 'False',
#   'FilteredWordsString': 'bon appétit gérard, pdt certains citoyens peine quoi manger l’#inflation presque tous (sauf élus) pénalisés  #senat #macronie #censurepopulaire #retraites',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 20:01:12'),
#   'Tweet Id': '1642588002294587393',
#   'Text': '"    ca me fait marrer ceux qui ont voulu de ce vaccin de m... et qui protestent maintenant contre la  ils ont pas pas écouté notre $$$ Président : ""le #covid est passé par là"" à votre avis ça veut dire quoi ? Que la dette elle va être remboursée par..."',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'lepindev',
#   'User_description': 'Tech & Bio',
#   'User_followersCount': 486,
#   'User_verified': 'False',
#   'FilteredWordsString': '"    ca fait marrer ceux voulu vaccin m... protestent maintenant contre  écouté $$$ président : ""le #covid passé là"" avis ça veut dire quoi ? dette va être remboursée par..."',
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-04-02 20:00:01'),
#   'Tweet Id': '1642587703874035712',
#   'Text': 'Rapporteras att det senare skanderades ”Macron demission” (Macron avgång) på Stade de France 49 min och 3 sek in i matchen i fotboll. 49.3 heter artikel i konstitutionen som premiärminister Borne åberopade 16:e mars. #Frankrike  ',
#   'Like Count': 0,
#   'Reply Count': 1,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'ingettroll',
#   'User_description': 'Nä, men nu är det ju snart val. Kanske dags att twittra lite på svenska. Ödmjuk.',
#   'User_followersCount': 9,
#   'User_verified': 'False',
#   'FilteredWordsString': 'rapporteras att det senare skanderades ”macron demission” (macron avgång) på stade france 49 min och 3 sek in i matchen i fotboll. 49.3 heter artikel i konstitutionen som premiärminister borne åberopade 16:e mars. #frankrike',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 19:58:04'),
#   'Tweet Id': '1642587215715770369',
#   'Text': '#Réformedesretraites #greve6avril #AssembleeNationale  Quand est ce que les oppositions politiques vont afin prendre leurs responsabilités en demandant la destitution de MACRON et de gouvernement, cela devient vital pour le pays et la paix sociale. ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': '63Cameleon',
#   'User_description': None,
#   'User_followersCount': 0,
#   'User_verified': 'False',
#   'FilteredWordsString': '#réformedesretraites #greve6avril #assembleenationale  quand oppositions politiques vont afin prendre leurs responsabilités demandant destitution macron gouvernement, cela devient vital pays paix sociale.',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:56:35'),
#   'Tweet Id': '1642586840786952198',
#   'Text': " alcune delle porcate di #Macron : limite del dibattito parlamentare, obbligo di pronunciazione sulla riforma in blocco e non per articolo e naturalmente l'articolo 49-3 che autorizza una legge senza il voto dei deputati!",
#   'Like Count': 1,
#   'Reply Count': 0,
#   'Retweet Count': 1,
#   'Quote Count': 0,
#   'User_username': 'flapox',
#   'User_description': 'Batterista Sociale #antifascista',
#   'User_followersCount': 259,
#   'User_verified': 'False',
#   'FilteredWordsString': " alcune delle porcate di #macron : limite del dibattito parlamentare, obbligo di pronunciazione sulla riforma in blocco e non per articolo e naturalmente l'articolo 49-3 che autorizza una legge senza voto dei deputati!",
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:52:44'),
#   'Tweet Id': '1642585874469724161',
#   'Text': '🔴 Voilà les POURRITURES qui gangrènent notre 5ème République 🤬 Ils sont aussi inutiles que corrompus ! Ils se battent car le changement signifierait leur disparition 🖕🤬  #Macron #France  #BRAVM #ReformeRetraites #Manifestations #ViolencesPolicieres #BRAV_M',
#   'Like Count': 1,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'TomB540',
#   'User_description': '🖕 Vive la France qui se révolte 🇫🇷                      #OM ⚽️ - #CAVS 🏀 - #BROWNS 🏈',
#   'User_followersCount': 80,
#   'User_verified': 'False',
#   'FilteredWordsString': '🔴 voilà pourritures gangrènent 5ème république 🤬 aussi inutiles corrompus ! battent car changement signifierait disparition 🖕🤬  #macron #france  #bravm #reformeretraites #manifestations #violencespolicieres #brav_m',
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:51:00'),
#   'Tweet Id': '1642585437658136576',
#   'Text': "Ok, vous refusez la  mais vous proposez quoi ? l'augmentation des impôts ou la baisse des pensions ? Soyez courageux et allez au bout de votre raisonnement        ",
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'Planete_B612',
#   'User_description': 'allumeur de réverbères ...',
#   'User_followersCount': 2,
#   'User_verified': 'False',
#   'FilteredWordsString': "ok, refusez  proposez quoi ? l'augmentation impôts baisse pensions ? courageux allez bout raisonnement",
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:50:17'),
#   'Tweet Id': '1642585254933196802',
#   'Text': ' #Manifestations 🇨🇵 #ViolencesPolicieres',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'ManuelleYerly',
#   'User_description': 'A quoi bon se résigner ? (100% connerie naturelle)🦰Pour une connerie démocratique. pour un numérique non fasciste.',
#   'User_followersCount': 201,
#   'User_verified': 'False',
#   'FilteredWordsString': ' #manifestations 🇨🇵 #violencespolicieres',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 19:46:47'),
#   'Tweet Id': '1642584375375134723',
#   'Text': '👍🤣#reformedesretraites #Macronie #retraites #censurepopulaire',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'zitounbraghini',
#   'User_description': None,
#   'User_followersCount': 18,
#   'User_verified': 'False',
#   'FilteredWordsString': '👍🤣#reformedesretraites #macronie #retraites #censurepopulaire',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 19:45:37'),
#   'Tweet Id': '1642584081538883587',
#   'Text': "Le Président est prisonnier du système de pensée 'du libre marché', ne comprend pas même son erreur. S'agit-il d'incompétence politique ? Doit-il envisager sa démission ?  #Retraites",
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'OlivierCollo',
#   'User_description': 'Militant politique',
#   'User_followersCount': 2,
#   'User_verified': 'False',
#   'FilteredWordsString': "président prisonnier système pensée 'du libre marché', comprend erreur. s'agit-il d'incompétence politique ? doit-il envisager démission ?  #retraites",
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:41:50'),
#   'Tweet Id': '1642583127972249601',
#   'Text': "M. Macron a clairement sous-estimé l'attachement des Français à leur système de retraites, joyau de notre modèle social (par ailleurs bien malmené). C'est une faute politique !  #Retraites",
#   'Like Count': 0,
#   'Reply Count': 1,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'OlivierCollo',
#   'User_description': 'Militant politique',
#   'User_followersCount': 2,
#   'User_verified': 'False',
#   'FilteredWordsString': "m. macron a clairement sous-estimé l'attachement français système retraites, joyau modèle social (par ailleurs bien malmené). c'est faute politique !  #retraites",
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:41:26'),
#   'Tweet Id': '1642583029976637442',
#   'Text': '😂  #Retraites #censurepopulaire #macronie #megabassines #eau',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'zitounbraghini',
#   'User_description': None,
#   'User_followersCount': 18,
#   'User_verified': 'False',
#   'FilteredWordsString': '😂  #retraites #censurepopulaire #macronie #megabassines #eau',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 19:39:41'),
#   'Tweet Id': '1642582588316426243',
#   'Text': '«\xa0Ils reculent l’âge de la retraite mais avancent l’âge de la mort\xa0»  #Retraites #RetraitDeLaReformeDesRetraites #ViolencesPolicieres #MacronDegage ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'asap_ajna',
#   'User_description': 'La dictature s’épanouit sur le terreau de l’ignorance - George Orwell',
#   'User_followersCount': 634,
#   'User_verified': 'False',
#   'FilteredWordsString': '«\xa0ils reculent l’âge retraite avancent l’âge mort\xa0»  #retraites #retraitdelareformedesretraites #violencespolicieres #macrondegage',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 19:39:26'),
#   'Tweet Id': '1642582525464784896',
#   'Text': "  qui invite  , un gars qui gagne 15 milles euros sur notre dos et ils pensent que l'on va l'écouter ??? Allez vous faire ....... ",
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'hohotweet',
#   'User_description': None,
#   'User_followersCount': 220,
#   'User_verified': 'False',
#   'FilteredWordsString': "  invite  , gars gagne 15 milles euros dos pensent l'on va l'écouter ??? allez faire .......",
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 19:38:53'),
#   'Tweet Id': '1642582388881387521',
#   'Text': " On est ici dans le cadre d'une action de déculpabilisation personnelle, avec en + le plaisir du déguisement : jusqu'à l'absurdité totale de dénigrer sa propre fonction, qui serait donc facile et le club Med toute l'année 🤔 ",
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'SL_1960',
#   'User_description': "Né en 1960 à Alger en France quand il y avait plein d'églises et de synagogues ! ✝️✡️☯️♎ (Je bloque dès la première insulte car c'est une inaptitude à débattre)",
#   'User_followersCount': 470,
#   'User_verified': 'False',
#   'FilteredWordsString': " ici cadre d'une action déculpabilisation personnelle, + plaisir déguisement : jusqu'à l'absurdité totale dénigrer propre fonction, donc facile club med toute l'année 🤔",
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:36:44'),
#   'Tweet Id': '1642581847556206594',
#   'Text': " Non mais il est surtout que les français n'ont pas donné de majorité absolue à l'assemblée nationale à Macron afin qu'il gouverne en coopération avec les autres forces politiques, l'utilisation du 49.3 pour faire passer la  prouve que Macron n'a pas compris ce…",
#   'Like Count': 1,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 1,
#   'User_username': 'ManuelleYerly',
#   'User_description': 'A quoi bon se résigner ? (100% connerie naturelle)🦰Pour une connerie démocratique. pour un numérique non fasciste.',
#   'User_followersCount': 201,
#   'User_verified': 'False',
#   'FilteredWordsString': " non surtout français n'ont donné majorité absolue l'assemblée nationale macron afin qu'il gouverne coopération autres forces politiques, l'utilisation 49.3 faire passer  prouve macron n'a compris ce…",
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:34:37'),
#   'Tweet Id': '1642581313403199489',
#   'Text': "😏😏😏👍 c'est un peu ça...#dictature  ",
#   'Like Count': 3,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 1,
#   'User_username': 'JASMilovavitch',
#   'User_description': 'les nationalistes haineux, passez votre chemin sous mes tweets. en Islam, le nationalisme est interdit 🚨',
#   'User_followersCount': 566,
#   'User_verified': 'False',
#   'FilteredWordsString': "😏😏😏👍 c'est peu ça...#dictature",
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:29:26'),
#   'Tweet Id': '1642580008039337985',
#   'Text': '  Rien ne va.  cette réforme des retraites  oblige à bosser jusqu a 65 ans et plus soit 5 ans de plus que nos parents pour une retraite 30% plus faible. Mais pour nos chers élus tout va bien.pas de réforme pour eux. ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'LespoPierre',
#   'User_description': 'Ami des animaux et de la nature. Soutien total à l ukraine. Pour la fraternité  et la bienveillance...si possible..',
#   'User_followersCount': 12,
#   'User_verified': 'False',
#   'FilteredWordsString': '  rien va.  cette réforme retraites  oblige bosser jusqu a 65 ans plus 5 ans plus parents retraite 30% plus faible. chers élus tout va bien.pas réforme eux.',
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:25:16'),
#   'Tweet Id': '1642578960876818436',
#   'Text': "C'est pire, car  utilise la double-pensée des staliniens : le faux est vrai et vice-versa, au final la dialectique a toujours raison. Si au pouvoir, il éliminerait ceux qui s'attaquent à la police, aussi.#SainteSoline ",
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 1,
#   'User_username': 'SL_1960',
#   'User_description': "Né en 1960 à Alger en France quand il y avait plein d'églises et de synagogues ! ✝️✡️☯️♎ (Je bloque dès la première insulte car c'est une inaptitude à débattre)",
#   'User_followersCount': 470,
#   'User_verified': 'False',
#   'FilteredWordsString': "c'est pire, car  utilise double-pensée staliniens : faux vrai vice-versa, final dialectique a toujours raison. si pouvoir, éliminerait ceux s'attaquent police, aussi.#saintesoline",
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:25:09'),
#   'Tweet Id': '1642578930300321794',
#   'Text': " C'est pire, car  utilise la double-pensée des staliniens : le faux est vrai et vice-versa, au final la dialectique a toujours raison. Si au pouvoir, il éliminerait ceux qui s'attaquent à la police, aussi.#SainteSoline ",
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'SL_1960',
#   'User_description': "Né en 1960 à Alger en France quand il y avait plein d'églises et de synagogues ! ✝️✡️☯️♎ (Je bloque dès la première insulte car c'est une inaptitude à débattre)",
#   'User_followersCount': 470,
#   'User_verified': 'False',
#   'FilteredWordsString': " c'est pire, car  utilise double-pensée staliniens : faux vrai vice-versa, final dialectique a toujours raison. si pouvoir, éliminerait ceux s'attaquent police, aussi.#saintesoline",
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:24:50'),
#   'Tweet Id': '1642578852475019266',
#   'Text': 'Sur BFM Gérard Larcher assure le SAV de la macronie sur la  ',
#   'Like Count': 41,
#   'Reply Count': 4,
#   'Retweet Count': 22,
#   'Quote Count': 2,
#   'User_username': 'nicolasputsch',
#   'User_description': "Fondateur de Putsch.media - Anime l'émission #Putsch Live, éditorialiste sur @Ligne__Droite et @GETTRofficial - anime l'actu invisible nicolasvidal.substack.com",
#   'User_followersCount': 33387,
#   'User_verified': 'False',
#   'FilteredWordsString': 'bfm gérard larcher assure sav macronie',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 19:24:50'),
#   'Tweet Id': '1642578849648070658',
#   'Text': 'Les médias à la solde de #Macron font tout pour éclipser la  en criminalisant la gauche #Nupes avec l’appui des hollandais du PS comme .',
#   'Like Count': 1,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'bto_nic',
#   'User_description': 'Juriste EN. égalité/ liberté / justice fiscale et sociale/ environnement/ laïcité 🇫🇷🇨🇦/ 🇫🇷🇧🇬🇪🇺🌱🐣compte perso ! #Nupes',
#   'User_followersCount': 253,
#   'User_verified': 'False',
#   'FilteredWordsString': 'médias solde #macron font tout éclipser  criminalisant gauche #nupes l’appui hollandais ps comme .',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:24:16'),
#   'Tweet Id': '1642578709478506498',
#   'Text': "Visite surprise d'Elisabeth #Borne  à #Vire #Normandie au lendemain de la manifestation contre la   via ",
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 1,
#   'User_username': 'Ludo_Lemoine',
#   'User_description': 'Editeur @lavoixlebocage @journaldelorne @lePublicateur @OrneCombattante @Gazette50 @lesnouvelles14 #journalisme #PHR #Hyperlocal #presse #numerique',
#   'User_followersCount': 383,
#   'User_verified': 'False',
#   'FilteredWordsString': "visite surprise d'elisabeth #borne  #vire #normandie lendemain manifestation contre   via",
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:21:04'),
#   'Tweet Id': '1642577903387828227',
#   'Text': " Si on avait consulté le peuple avant d'imposer la  par le 49.3, y aurait pas eu de manifs monstres ni de violences 😏",
#   'Like Count': 4,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'beauregard_luci',
#   'User_description': 'Là où je viens poser des pensées, donner des avis, discuter et rigoler. Tout ça toujours dans le respect 🙃😀😊',
#   'User_followersCount': 110,
#   'User_verified': 'False',
#   'FilteredWordsString': " si consulté peuple avant d'imposer  49.3, manifs monstres ni violences 😏",
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:15:51'),
#   'Tweet Id': '1642576590285447174',
#   'Text': 'Dixit un macroniste bon suceur. 0 crédit. #NousReussirons #Renaissance #Schiappa ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'sbastien_xD',
#   'User_description': 'Pousseur social.',
#   'User_followersCount': 0,
#   'User_verified': 'False',
#   'FilteredWordsString': 'dixit macroniste bon suceur. 0 crédit. #nousreussirons #renaissance #schiappa',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:12:51'),
#   'Tweet Id': '1642575834367008772',
#   'Text': 'Puis, direction Place de la République pour prendre part à la grande manifestation contre la  aux côtés des organisations syndicales. Une ambiance bon enfant mais déterminée face à la volonté affichée du gouvernement de passer en force. ',
#   'Like Count': 5,
#   'Reply Count': 1,
#   'Retweet Count': 1,
#   'Quote Count': 0,
#   'User_username': 'SamyAhmar',
#   'User_description': 'Head of Health @SaveChildrenUK, Co-Chair @ORSZCA, Global Health, Inequality 🌍 | Élu AFE pour les Français·es du Royaume-Uni | 🇫🇷🇬🇧🇲🇦🇪🇺 | Views=own',
#   'User_followersCount': 1903,
#   'User_verified': 'False',
#   'FilteredWordsString': 'puis, direction place république prendre part grande manifestation contre  côtés organisations syndicales. ambiance bon enfant déterminée face volonté affichée gouvernement passer force.',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:12:46'),
#   'Tweet Id': '1642575815471661057',
#   'Text': '👍#reformedesretraites #retraites #censurepopulaire #macronie',
#   'Like Count': 1,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'zitounbraghini',
#   'User_description': None,
#   'User_followersCount': 18,
#   'User_verified': 'False',
#   'FilteredWordsString': '👍#reformedesretraites #retraites #censurepopulaire #macronie',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 19:12:15'),
#   'Tweet Id': '1642575686186483712',
#   'Text': 'Arrivée à Paris le dimanche 26, dans une ville sous tension, avec la mobilisation sociale contre la  en lame de fond. Les éboueurs, en grève depuis plusieurs jours, nous mettent face à nos modes de consommation, qui génèrent des montagnes de déchets. ',
#   'Like Count': 3,
#   'Reply Count': 1,
#   'Retweet Count': 1,
#   'Quote Count': 0,
#   'User_username': 'SamyAhmar',
#   'User_description': 'Head of Health @SaveChildrenUK, Co-Chair @ORSZCA, Global Health, Inequality 🌍 | Élu AFE pour les Français·es du Royaume-Uni | 🇫🇷🇬🇧🇲🇦🇪🇺 | Views=own',
#   'User_followersCount': 1903,
#   'User_verified': 'False',
#   'FilteredWordsString': 'arrivée paris dimanche 26, ville sous tension, mobilisation sociale contre  lame fond. éboueurs, grève depuis plusieurs jours, mettent face modes consommation, génèrent montagnes déchets.',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:12:00'),
#   'Tweet Id': '1642575622483353600',
#   'Text': 'Vad jag förstår funderades det på om Macron skulle närvara vid matchen i fotboll mellan Frankrike och Holland 24:e mars. I artikel publicerad på matchdagen uppges att han avsåg att inte göra det. #protest #Frankrike  #Manifestations ',
#   'Like Count': 0,
#   'Reply Count': 1,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'ingettroll',
#   'User_description': 'Nä, men nu är det ju snart val. Kanske dags att twittra lite på svenska. Ödmjuk.',
#   'User_followersCount': 9,
#   'User_verified': 'False',
#   'FilteredWordsString': 'vad jag förstår funderades det på om macron skulle närvara vid matchen i fotboll mellan frankrike och holland 24:e mars. i artikel publicerad på matchdagen uppges att han avsåg att inte göra det. #protest #frankrike  #manifestations',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 17:05:39'),
#   'Tweet Id': '1642543823287902208',
#   'Text': '23/04/02-17H05  #photodujour #Macron13h #RéformeDesRetraites ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'jp91310',
#   'User_description': None,
#   'User_followersCount': 1,
#   'User_verified': 'False',
#   'FilteredWordsString': '23/04/02-17h05  #photodujour #macron13h #réformedesretraites',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 19:07:36'),
#   'Tweet Id': '1642574515153559554',
#   'Text': ' : 📹 La majorité des députés sont contre la #RéformeDesRetraites, mais aussi 94% des actifs et 70% des Français. Rien que cela devrait faire renoncer Emmanuel Macron !  ',
#   'Like Count': 1,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'FNLavaurPteTarn',
#   'User_description': 'Compte officiel des cantons Les Portes du Tarn & Lavaur Cocagne - Cantons rattachées à la Fédération Front National du #Tarn @FNTarn',
#   'User_followersCount': 558,
#   'User_verified': 'False',
#   'FilteredWordsString': ' : 📹 majorité députés contre #réformedesretraites, aussi 94% actifs 70% français. rien cela devrait faire renoncer emmanuel macron !',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:06:52'),
#   'Tweet Id': '1642574328993652742',
#   'Text': '📹 La majorité des députés sont contre la #RéformeDesRetraites, mais aussi 94% des actifs et 70% des Français. Rien que cela devrait faire renoncer Emmanuel Macron !  ',
#   'Like Count': 284,
#   'Reply Count': 17,
#   'Retweet Count': 134,
#   'Quote Count': 3,
#   'User_username': 'MLP_officiel',
#   'User_description': 'Député et conseillère départementale du Pas-de-Calais. Présidente du groupe RN à l’Assemblée nationale.',
#   'User_followersCount': 2909453,
#   'User_verified': 'True',
#   'FilteredWordsString': '📹 majorité députés contre #réformedesretraites, aussi 94% actifs 70% français. rien cela devrait faire renoncer emmanuel macron !',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 19:06:24'),
#   'Tweet Id': '1642574213688033281',
#   'Text': '#MarleneSchiappa  #Macron_Ordure à médité mes ratons Pfizer ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'Gta84000',
#   'User_description': 'No comment',
#   'User_followersCount': 7,
#   'User_verified': 'False',
#   'FilteredWordsString': '#marleneschiappa  #macron_ordure médité ratons pfizer',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 19:05:36'),
#   'Tweet Id': '1642574009811230724',
#   'Text': '23/04/02-19H05  #photodujour #Macron13h #RéformeDesRetraites ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'jp91310',
#   'User_description': None,
#   'User_followersCount': 1,
#   'User_verified': 'False',
#   'FilteredWordsString': '23/04/02-19h05  #photodujour #macron13h #réformedesretraites',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 19:03:08'),
#   'Tweet Id': '1642573390350372869',
#   'Text': 'Contrairement à la NUPES, le  n’a pas eu besoin d’hurler matin, midi et soir et de transformer l’Assemblée nationale en ZAD pour prouver son opposition à la . ',
#   'Like Count': 23,
#   'Reply Count': 1,
#   'Retweet Count': 1,
#   'Quote Count': 0,
#   'User_username': 'CColombier_RN',
#   'User_description': 'Députée de la Charente 🇫🇷 | VP du groupe RN à l’Assemblée Nationale | Conseillère régionale @RNational_NA | Membre du Bureau National et Porte-Parole du RN',
#   'User_followersCount': 3957,
#   'User_verified': 'True',
#   'FilteredWordsString': 'contrairement nupes,  n’a besoin d’hurler matin, midi soir transformer l’assemblée nationale zad prouver opposition .',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 19:02:02'),
#   'Tweet Id': '1642573114235138049',
#   'Text': ' comment se mec peut défendre les policiers quand il viole il tape sont raison insulte xt il devrait démissionné ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'Ps5Wolong',
#   'User_description': 'Jeux PS 5',
#   'User_followersCount': 1,
#   'User_verified': 'False',
#   'FilteredWordsString': ' comment mec peut défendre policiers quand viole tape raison insulte xt devrait démissionné',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 18:58:52'),
#   'Tweet Id': '1642572316101033990',
#   'Text': '#Paris  #BRAV_M  #manifestation #manif6avril petit souvenir de Paris pour les touristes 😪😪😪 ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'asticot751',
#   'User_description': 'old fat and stupid, lol',
#   'User_followersCount': 32,
#   'User_verified': 'False',
#   'FilteredWordsString': '#paris  #brav_m  #manifestation #manif6avril petit souvenir paris touristes 😪😪😪',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 18:57:53'),
#   'Tweet Id': '1642572069769551872',
#   'Text': '#reformedesretraites je suis mdr il donne le droit de voter pour des trotinette mes pas pour la retraite il se fou de nous gl un truc que en sont bah les c... ',
#   'Like Count': 1,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'Ps5Wolong',
#   'User_description': 'Jeux PS 5',
#   'User_followersCount': 1,
#   'User_verified': 'False',
#   'FilteredWordsString': '#reformedesretraites mdr donne droit voter trotinette retraite fou gl truc bah c...',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 18:57:38'),
#   'Tweet Id': '1642572006288760833',
#   'Text': 'Humeur noire #rameaux #borne #reformedesretraites #actu ',
#   'Like Count': 51,
#   'Reply Count': 0,
#   'Retweet Count': 7,
#   'Quote Count': 0,
#   'User_username': 'EmmanuelChaunu',
#   'User_description': 'Chaunu est le seul dessinateur de presse à monter sur scène pour allier dessin en direct et humour décalé ...chroniqueur Vivement Dimanche',
#   'User_followersCount': 14073,
#   'User_verified': 'False',
#   'FilteredWordsString': 'humeur noire #rameaux #borne #reformedesretraites #actu',
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-04-02 18:57:22'),
#   'Tweet Id': '1642571941075714049',
#   'Text': "Deux années de + de souffrance ou à produire de la valeur pour l'actionnaire! Issu d'un article de #BenoîtBréville sur #lemondediplomatique  ",
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'flapox',
#   'User_description': 'Batterista Sociale #antifascista',
#   'User_followersCount': 259,
#   'User_verified': 'False',
#   'FilteredWordsString': "deux années + souffrance produire valeur l'actionnaire! issu d'un article #benoîtbréville #lemondediplomatique",
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 18:56:57'),
#   'Tweet Id': '1642571832686518273',
#   'Text': "Enquête interne au #S2DE sur la participation à la journée du jeudi #6avril. Voulez-vous que notre syndicat continue à appeler à la mobilisation contre la  ? Oui 6⃣4⃣%, Sans Avis 2⃣5⃣%, Non 1⃣1⃣%. Par ce vote interne, le choix est clair➡️c'est toujours NON !",
#   'Like Count': 3,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 's2de2021',
#   'User_description': "Le Syndicat des Directrices et Directeurs d'École, #S2DÉ, a été fondé le 10 juillet 2021. Il a vocation à améliorer le quotidien de la direction d’école.",
#   'User_followersCount': 2314,
#   'User_verified': 'False',
#   'FilteredWordsString': "enquête interne #s2de participation journée jeudi #6avril. voulez-vous syndicat continue appeler mobilisation contre  ? oui 6⃣4⃣%, sans avis 2⃣5⃣%, non 1⃣1⃣%. vote interne, choix clair➡️c'est toujours non !",
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-04-02 18:51:33'),
#   'Tweet Id': '1642570474361069569',
#   'Text': 'Dessin du dimanche  #conseilconstitutionnel #Retraites  #dimanche #reforme #Constitution #fabius #loto #FDJ #loi #DessinDePresse #dessin ',
#   'Like Count': 1,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'PEZdessinateur',
#   'User_description': "Dessins de presse et d'humour",
#   'User_followersCount': 217,
#   'User_verified': 'False',
#   'FilteredWordsString': 'dessin dimanche  #conseilconstitutionnel #retraites  #dimanche #reforme #constitution #fabius #loto #fdj #loi #dessindepresse #dessin',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 18:50:57'),
#   'Tweet Id': '1642570324259528704',
#   'Text': 'Quel homme éclairé ! 🤣   #censurepopulaire  #eau #megabassines #macronie  ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'zitounbraghini',
#   'User_description': None,
#   'User_followersCount': 18,
#   'User_verified': 'False',
#   'FilteredWordsString': 'quel homme éclairé ! 🤣   #censurepopulaire  #eau #megabassines #macronie',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 18:48:13'),
#   'Tweet Id': '1642569637295448067',
#   'Text': 'égalité salariale entre les sexes, il est vrai que si les femmes gagnaient autant que les hommes pour un travail égal, cela pourrait contribuer à augmenter les cotisations sociales et donc à financer le système de retraite. 6M€ ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'dieuxxueid',
#   'User_description': None,
#   'User_followersCount': 4,
#   'User_verified': 'False',
#   'FilteredWordsString': 'égalité salariale entre sexes, vrai si femmes gagnaient autant hommes travail égal, cela pourrait contribuer augmenter cotisations sociales donc financer système retraite. 6m€',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 18:47:38'),
#   'Tweet Id': '1642569491845398534',
#   'Text': "Contre cette  en Val d'Oise toujours mobilisés  ⤵️ ",
#   'Like Count': 5,
#   'Reply Count': 0,
#   'Retweet Count': 2,
#   'Quote Count': 1,
#   'User_username': 'GSvaldoise',
#   'User_description': None,
#   'User_followersCount': 306,
#   'User_verified': 'False',
#   'FilteredWordsString': "contre cette  val d'oise toujours mobilisés  ⤵️",
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 18:45:59'),
#   'Tweet Id': '1642569075632009216',
#   'Text': '#macron #reforme #ReformedesRetraites #bordeaux',
#   'Like Count': 6,
#   'Reply Count': 0,
#   'Retweet Count': 3,
#   'Quote Count': 0,
#   'User_username': 'AF_Bordeaux',
#   'User_description': "Compte officiel de l'Action française - Bordeaux | Fédération Aquitaine | #CercleMontesquiou facebook.com/actionfrancais…",
#   'User_followersCount': 2639,
#   'User_verified': 'False',
#   'FilteredWordsString': '#macron #reforme #reformedesretraites #bordeaux',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 18:45:40'),
#   'Tweet Id': '1642568994879156224',
#   'Text': ' Assumer ce bien jolie mais trainer un SDF et le traité de sac à merde normal quoi le mec assume tout Va bien alors  #ViolencesPolicieres lui coche toutes les cases',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'kobra381',
#   'User_description': None,
#   'User_followersCount': 29,
#   'User_verified': 'False',
#   'FilteredWordsString': ' assumer bien jolie trainer sdf traité sac merde normal quoi mec assume tout va bien alors  #violencespolicieres coche toutes cases',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 18:43:48'),
#   'Tweet Id': '1642568527201615872',
#   'Text': 'Augmenter les cotisations sociales 1% : Les cotisations sociales sont une source importante de financement des régimes de retraite en France. Augmenter le taux de cotisation pourrait aider à générer plus de revenus pour le système de retraite. 27 M€ ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'dieuxxueid',
#   'User_description': None,
#   'User_followersCount': 4,
#   'User_verified': 'False',
#   'FilteredWordsString': 'augmenter cotisations sociales 1% : cotisations sociales source importante financement régimes retraite france. augmenter taux cotisation pourrait aider générer plus revenus système retraite. 27 m€',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-04-02 18:43:13'),
#   'Tweet Id': '1642568376840077315',
#   'Text': '#greve  #Stop64ans ',
#   'Like Count': 2,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'ericthouzeau',
#   'User_description': 'Militant syndical (CGT) et politique (GDS)',
#   'User_followersCount': 1720,
#   'User_verified': 'False',
#   'FilteredWordsString': '#greve  #stop64ans',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-04-02 18:41:51'),
#   'Tweet Id': '1642568033896939521',
#   'Text': "    Faux, toutes les réformes des retraites promulguées n'ont jamais été défaites par les oppositions quand elles sont arrivées au pouvoir. Il n' y aura aucune exception à la règle. #RéformedesRetraites",
#   'Like Count': 1,
# ...
#   'Like Count': 2,
#   'Reply Count': 0,
#   'Retweet Count': 2,
#   'Quote Count': 0,
#   'User_username': 'Hippocampepour1',
#   'User_description': '"""Que la TERRE est belle ... le paradis de l’Univers !""""Je déteste l’injustice sous toutes ses formes""""Le présent est le ♥️ de notre vie…"""',
#   'User_followersCount': 2547,
#   'User_verified': 'False',
#   'FilteredWordsString': "soutien total manifestants d' #albi ! #france #greve6avril  #soignantssuspendus #violencespoliceres",
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-03-31 20:08:34'),
#   'Tweet Id': '1641865081209118723',
#   'Text': 'Demain soir à Savennieres pour une soirée de soutien  #greve6avril #Angers',
#   'Like Count': 10,
#   'Reply Count': 1,
#   'Retweet Count': 8,
#   'Quote Count': 0,
#   'User_username': 'AGgrevistes49',
#   'User_description': 'AG des enseignants grévistes du Maine et Loire',
#   'User_followersCount': 424,
#   'User_verified': 'False',
#   'FilteredWordsString': 'demain soir savennieres soirée soutien  #greve6avril #angers',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-03-31 20:08:25'),
#   'Tweet Id': '1641865045444288512',
#   'Text': 'C’est quoi ce cirque médiatique pour donner mauvaise conscience à propos  ? Les pays avec qui l’on nous compare étaient il y a peu des monarchies ou des dictatures ! Il faut comparer ce qui est comparable, les français cotisent PLUS et depuis des décennies ! ',
#   'Like Count': 17,
#   'Reply Count': 2,
#   'Retweet Count': 7,
#   'Quote Count': 1,
#   'User_username': '_C_VIAL',
#   'User_description': "Chef d'entreprise à la retraite. Réfractaire à Macron et à tout despotisme de droite ou de gauche. PAS DE DM ! Mon blog ⬇️⬇️⬇️",
#   'User_followersCount': 3827,
#   'User_verified': 'False',
#   'FilteredWordsString': 'c’est quoi cirque médiatique donner mauvaise conscience propos  ? pays l’on compare a peu monarchies dictatures ! faut comparer comparable, français cotisent plus depuis décennies !',
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-03-31 20:05:49'),
#   'Tweet Id': '1641864390231089176',
#   'Text': '23/03/31-20H05 . #photodujour #Macron13h #RéformeDesRetraites ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 1,
#   'Quote Count': 0,
#   'User_username': 'jp91310',
#   'User_description': None,
#   'User_followersCount': 1,
#   'User_verified': 'False',
#   'FilteredWordsString': '23/03/31-20h05 . #photodujour #macron13h #réformedesretraites',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-03-31 20:05:15'),
#   'Tweet Id': '1641864246827835395',
#   'Text': "Pour , je suis revenue sur la venue de Jean-Marc Rouillan, terroriste d'extrême-gauche, condamné en 1989 pour complicité d'assassinat, sur un campus de l'Université de #Bordeaux. La lutte contre la  mérite mieux  ",
#   'Like Count': 41,
#   'Reply Count': 2,
#   'Retweet Count': 8,
#   'Quote Count': 1,
#   'User_username': 'jrechagneux',
#   'User_description': 'Conseillère municipale de Lormont • Conseillère régionale RN de Nouvelle-Aquitaine • DD Adjointe du RN Gironde',
#   'User_followersCount': 6217,
#   'User_verified': 'False',
#   'FilteredWordsString': ", revenue venue jean-marc rouillan, terroriste d'extrême-gauche, condamné 1989 complicité d'assassinat, campus l'université #bordeaux. lutte contre  mérite mieux",
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-03-31 20:00:02'),
#   'Tweet Id': '1641862933259902977',
#   'Text': '#greve  l Mouvement social du 3 avril : Faisons un point sur la restauration dans les écoles ➡️  ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'mairievitry',
#   'User_description': '🏛 Compte officiel de Vitry-sur-Seine, la plus grande ville du @valdemarne_94',
#   'User_followersCount': 4157,
#   'User_verified': 'False',
#   'FilteredWordsString': '#greve  mouvement social 3 avril : faisons point restauration écoles ➡️',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-03-31 19:58:11'),
#   'Tweet Id': '1641862469076279301',
#   'Text': 'Qui dirigera la France après Macron ?  #greve6avril #manifestation #Paris #Lyon #Lille #Bordeaux #Marseille #PlanEau #ViolencesPolicières #1eravril #Borne',
#   'Like Count': 2,
#   'Reply Count': 5,
#   'Retweet Count': 2,
#   'Quote Count': 0,
#   'User_username': 'jacryno',
#   'User_description': '"""À la sieste comme à la sieste"" 🐞🍀✝️🤞🧲❤️🪙 ""C\'est le pompon sur la cerise du gâteau"""',
#   'User_followersCount': 3,
#   'User_verified': 'False',
#   'FilteredWordsString': 'dirigera france après macron ?  #greve6avril #manifestation #paris #lyon #lille #bordeaux #marseille #planeau #violencespolicières #1eravril #borne',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-03-31 19:56:57'),
#   'Tweet Id': '1641862157502406670',
#   'Text': "   Sachez que le lien avec le CAC40 est au beau fixe, n'ayez crainte, vous devriez plutôt enlever votre  et essayer de renouer le lien avec les vrais français qui font la fortune de ceux que vous protégez...Quel vaste chantier!!...Bon courage🤑🔼",
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'TikTokF39235719',
#   'User_description': "Thalès de Milet a établi l'eau comme principe fondateur de toutes choses. Pour lui, l'humidité est l'aliment de tous les êtres. #Thalès #Philosophie #Eau",
#   'User_followersCount': 8,
#   'User_verified': 'False',
#   'FilteredWordsString': "   sachez lien cac40 beau fixe, n'ayez crainte, devriez plutôt enlever  essayer renouer lien vrais français font fortune ceux protégez...quel vaste chantier!!...bon courage🤑🔼",
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-03-31 19:50:46'),
#   'Tweet Id': '1641860604154503174',
#   'Text': " a voulue défendre la  en disant l'Espagne et le portugal ils partent plus tard , heureusement que  lui ai fait fermé sa gueule en lui fesant le rapel des annuités dans ces pays !!! Bravo valerie pour 1 fois ...  ",
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'hohotweet',
#   'User_description': None,
#   'User_followersCount': 220,
#   'User_verified': 'False',
#   'FilteredWordsString': " a voulue défendre  disant l'espagne portugal partent plus tard , heureusement  fait fermé gueule fesant rapel annuités pays !!! bravo valerie 1 fois ...",
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-03-31 19:47:17'),
#   'Tweet Id': '1641859727427510274',
#   'Text': "Non c'est un fake c'est pas possible... 😂🤣  #CGT",
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'TheRaisX',
#   'User_description': '#FreePalestine 🇵🇸 #FreeAssange',
#   'User_followersCount': 84,
#   'User_verified': 'False',
#   'FilteredWordsString': "non c'est fake c'est possible... 😂🤣  #cgt",
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-03-31 19:46:18'),
#   'Tweet Id': '1641859476473913345',
#   'Text': ' Non à la ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'ZOUICZOUICZOUIC',
#   'User_description': None,
#   'User_followersCount': 89,
#   'User_verified': 'False',
#   'FilteredWordsString': ' non',
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-03-31 19:46:14'),
#   'Tweet Id': '1641859459369639937',
#   'Text': 'Commencer à arrêter les canons à eaux sur les manifestants, on commence par la l économie d eau? #macron #ecowatt  #manif6avril',
#   'Like Count': 1,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'efficience422',
#   'User_description': "#Think while it's still legal/  #LGBT 👻#NonALaVaccinationObligatoire #SansMacron2022",
#   'User_followersCount': 178,
#   'User_verified': 'False',
#   'FilteredWordsString': 'commencer arrêter canons eaux manifestants, commence économie eau? #macron #ecowatt  #manif6avril',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-03-31 19:45:04'),
#   'Tweet Id': '1641859166510669841',
#   'Text': ' Compte tenu de la  , personnellement,  je suis en retraite dès maintenant en faisant le moins possible et en profitant davantage de ma vie ! Fallait pas jouer aux cons ! #VieDeProfs coucou   #NonAuPacteEnseignant',
#   'Like Count': 16,
#   'Reply Count': 1,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'lvk_res',
#   'User_description': '#professeur #lettres #LCA #FLE #Théâtre  - taquine consternante #TeamConsternants #JeSuisLatiniste et #Demeter in #LesImmortels #college2016 #PasDeVagues #CGT',
#   'User_followersCount': 3234,
#   'User_verified': 'False',
#   'FilteredWordsString': ' compte tenu  , personnellement,  retraite dès maintenant faisant moins possible profitant davantage vie ! fallait jouer cons ! #viedeprofs coucou   #nonaupacteenseignant',
#   'sentiment_class': 'Insatisfait'},
#  {'Datetime': Timestamp('2023-03-31 19:42:50'),
#   'Tweet Id': '1641858604582985738',
#   'Text': ' On demande le retrait point barre ! #ReformedesRetraites #greve28mars',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'ZOUICZOUICZOUIC',
#   'User_description': None,
#   'User_followersCount': 89,
#   'User_verified': 'False',
#   'FilteredWordsString': ' demande retrait point barre ! #reformedesretraites #greve28mars',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-03-31 19:39:02'),
#   'Tweet Id': '1641857649720320008',
#   'Text': 'Viens découvrir pourquoi #Macron est un génie !  Après Macron #aprèsmacron ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'Le_Consigliere_',
#   'User_description': "Je fournis des analyses sur des sujets d'actualité.",
#   'User_followersCount': 11,
#   'User_verified': 'False',
#   'FilteredWordsString': 'viens découvrir pourquoi #macron génie !  après macron #aprèsmacron',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-03-31 19:37:33'),
#   'Tweet Id': '1641857277354287104',
#   'Text': 'Viens découvrir comment #Macron nous trolle !  Après Macron #aprèsmacron ',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'Le_Consigliere_',
#   'User_description': "Je fournis des analyses sur des sujets d'actualité.",
#   'User_followersCount': 11,
#   'User_verified': 'False',
#   'FilteredWordsString': 'viens découvrir comment #macron trolle !  après macron #aprèsmacron',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-03-31 19:36:12'),
#   'Tweet Id': '1641856937514917891',
#   'Text': 'Concert bèglais en solidarité avec les grévistes.  ',
#   'Like Count': 6,
#   'Reply Count': 1,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'BatienSanzes',
#   'User_description': '#VeloTaf #GavéMalGaré 🚶🚲🦽  #MétropoleMillionnaire et quelques autres sujets.',
#   'User_followersCount': 216,
#   'User_verified': 'False',
#   'FilteredWordsString': 'concert bèglais solidarité grévistes.',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-03-31 19:32:22'),
#   'Tweet Id': '1641855969624719370',
#   'Text': "Au nom du maintien de l'ordre | ARTE  via  #ViolencesPolicières #manifestation #manifestations ",
#   'Like Count': 1,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'StudiShou',
#   'User_description': '🐙 Geek artist. Like art, #PixelArt, #painting & #drawing.🦑🤖 Chercheuse ès Arts, Humanités et Société. Ing. Spé: robots, SF et Steampunk. ⚙️ Dépressive. THPI.',
#   'User_followersCount': 840,
#   'User_verified': 'False',
#   'FilteredWordsString': "nom maintien l'ordre | arte  via  #violencespolicières #manifestation #manifestations",
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-03-31 19:32:06'),
#   'Tweet Id': '1641855905128906767',
#   'Text': '👍#reformedesretraites #retraites #Macronie #CensurePopulaire',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'zitounbraghini',
#   'User_description': None,
#   'User_followersCount': 18,
#   'User_verified': 'False',
#   'FilteredWordsString': '👍#reformedesretraites #retraites #macronie #censurepopulaire',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-03-31 19:31:12'),
#   'Tweet Id': '1641855678762319882',
#   'Text': "#Schiappa dans playboy alors que la  et l'inflation foutent les français à poil #manifestation #greve6avril Qu'ils dégagent tous ! ",
#   'Like Count': 8,
#   'Reply Count': 0,
#   'Retweet Count': 7,
#   'Quote Count': 0,
#   'User_username': 'didierLEROY8',
#   'User_description': 'Déjà 8 ou 9 doses de retard. Me soigne à la biniouse bzh et au pâté Hénaff, me tiens éloigné du journalisme subventionné et emmerde Macron avec délectation.',
#   'User_followersCount': 497,
#   'User_verified': 'False',
#   'FilteredWordsString': "#schiappa playboy alors  l'inflation foutent français poil #manifestation #greve6avril qu'ils dégagent tous !",
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-03-30 07:30:24'),
#   'Tweet Id': '1641311894970540034',
#   'Text': '#DarmaninDemission  #SainteSoline ',
#   'Like Count': 3,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'Roldynatueur',
#   'User_description': 'Grand frère de Skynet',
#   'User_followersCount': 3,
#   'User_verified': 'False',
#   'FilteredWordsString': '#darmanindemission  #saintesoline',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-03-31 19:27:34'),
#   'Tweet Id': '1641854765268074505',
#   'Text': '👍 le pouvoir décadent a peur de ce qu’il n’arrive pas à maîtriser et qui réussit à s’opposer à sa nuisance pour l’environnement et les citoyens 😉 #Retraites #Referendum #RIP #CensurePopulaire #Macronie',
#   'Like Count': 0,
#   'Reply Count': 1,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'zitounbraghini',
#   'User_description': None,
#   'User_followersCount': 18,
#   'User_verified': 'False',
#   'FilteredWordsString': '👍 pouvoir décadent a peur qu’il n’arrive maîtriser réussit s’opposer nuisance l’environnement citoyens 😉 #retraites #referendum #rip #censurepopulaire #macronie',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-03-31 19:23:44'),
#   'Tweet Id': '1641853799265337364',
#   'Text': ' La cgt est fiable. La cfdt ??. Enfin jusqu a présent elle l est...on verra....',
#   'Like Count': 1,
#   'Reply Count': 0,
#   'Retweet Count': 1,
#   'Quote Count': 0,
#   'User_username': 'LespoPierre',
#   'User_description': 'Ami des animaux et de la nature. Soutien total à l ukraine. Pour la fraternité  et la bienveillance...si possible..',
#   'User_followersCount': 12,
#   'User_verified': 'False',
#   'FilteredWordsString': ' cgt fiable. cfdt ??. enfin jusqu a présent est...on verra....',
#   'sentiment_class': 'Satisfait'},
#  {'Datetime': Timestamp('2023-03-26 03:29:12'),
#   'Tweet Id': '1639801641657401344',
#   'Text': '👍 #retraites #referendum #RIP #censurepopulaire #Macronie',
#   'Like Count': 0,
#   'Reply Count': 0,
#   'Retweet Count': 0,
#   'Quote Count': 0,
#   'User_username': 'zitounbraghini',
#   'User_description': None,
#   'User_followersCount': 18,
#   'User_verified': 'False',
#   'FilteredWordsString': '👍 #retraites #referendum #rip #censurepopulaire #macronie',
#   'sentiment_class': 'Neutre'},
#  {'Datetime': Timestamp('2023-03-31 19:21:55'),
#   'Tweet Id': '1641853339791917078',
#   'Text': 'L’Etat totalitaire est en marche ! 😤👎 cette réponse disproportionnée pour intimider est illégale : Jupiter ! la protection du droit de blasphème ne s’applique pas que pour les religions 🙄 #Retraites #Referendum #RIP #CensurePopulaire #Macronie',
#   'Like Count': 1,
#   'Reply Count': 0,
#   'Retweet Count': 1,
#   'Quote Count': 0,
#   'User_username': 'zitounbraghini',
#   'User_description': None,
#   'User_followersCount': 18,
#   'User_verified': 'False',
#   'FilteredWordsString': 'l’etat totalitaire marche ! 😤👎 cette réponse disproportionnée intimider illégale : jupiter ! protection droit blasphème s’applique religions 🙄 #retraites #referendum #rip #censurepopulaire #macronie',
#   'sentiment_class': 'Satisfait'},
#  ...]

# %%
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'twitter_analysis')

# %%
db.data.insert_many(data)
